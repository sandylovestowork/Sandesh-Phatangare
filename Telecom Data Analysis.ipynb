# %%
import pandas as pd

# %%
df = pd.read_csv("C://Users//DELL//Desktop//top mentor//Telecom retention_Telco Company .csv")

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
telecom_data = df.copy()

# %%
telecom_data.shape
# Out:
# (2666, 20)

# %%
telecom_data['Churn'] = telecom_data['Churn'].astype('int64')

# %%
telecom_data.head(n= 2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
telecom_data.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %%
#### Average Call - Day/Evening/ Night - Approx 100 Calls
#### Average Charges - Day - 31
                      # Evening - 17
    ### Night - 9
    ###Cost/ Per customer = 100/31 - Day
    ###100/9    ,100/17

# %%
100.106152/9.052689
# Out:
# 11.058167578716112

# %%
#### Customers Churned and Customer Retained
telecom_data['Churn'].value_counts(normalize = True)
### Around - 2278 Customer are being retained - 85%
#### 388 -  Customers are being Churned out - 15%
# Out:
# 0    0.854464
# 1    0.145536
# Name: Churn, dtype: float64

# %%
Top_5_Sates = telecom_data.sort_values(by = 'Total day charge', ascending = False).head(5)
Top_5_Sates
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 296     CO             154        415                 No              No
# 780     NY              64        415                Yes              No
# 2087    OH             115        510                Yes              No
# 128     OH              83        415                 No              No
# 485     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 296                       0              350.8               75
# 780                       0              346.8               55
# 2087                      0              345.3               81
# 128                       0              337.4              120
# 485                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
Top_5_Sates = telecom_data.sort_values(by = 'Total eve charge', ascending = False).head(5)
Top_5_Sates
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2202    NC             130        408                Yes              No
# 2054    MD             102        415                 No              No
# 1269    AR              99        510                Yes              No
# 6       MA             121        510                 No             Yes
# 465     IN             113        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2202                      0              216.2              106
# 2054                      0              129.5               56
# 1269                      0              242.3              102
# 6                        24              218.2               88
# 465                       0              209.4              151
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
Top_5_Sates = telecom_data.sort_values(by = 'Total night charge', ascending = False).head(5)
Top_5_Sates
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2142    VA             172        510                 No              No
# 1035    NE              89        415                 No             Yes
# 1137    ID              55        510                 No             Yes
# 2495    GA              73        408                 No              No
# 733     WI              80        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2142                      0              169.8              123
# 1035                     29              163.5               80
# 1137                      8              222.5              104
# 2495                      0              157.6               92
# 733                       0              239.9              121
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
Top_5_Sates = telecom_data.sort_values(by = ['Churn','Total day charge'], ascending = [False,False]).head(5)
Top_5_Sates
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 296     CO             154        415                 No              No
# 780     NY              64        415                Yes              No
# 2087    OH             115        510                Yes              No
# 128     OH              83        415                 No              No
# 485     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 296                       0              350.8               75
# 780                       0              346.8               55
# 2087                      0              345.3               81
# 128                       0              337.4              120
# 485                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
Top_5_Sates = telecom_data.sort_values(by = ['Churn','Total night calls'], ascending = [False,False]).head(5)
Top_5_Sates
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 713     CT              23        510                 No              No
# 268     AL              86        415                 No              No
# 1589    TX              73        408                 No              No
# 578     KY              91        415                Yes              No
# 2352    NY             168        408                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 713                       0              321.6              107
# 268                       0              128.3              121
# 1589                      0              286.4              109
# 578                       0              145.0               89
# 2352                      0              163.4              134
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
telecom_data['Churn'].mean()
# Out:
# 0.145536384096024

# %%
### Churn Analysis of All the Columns
telecom_data[telecom_data['Churn']== 1].mean()
# Out:
# Account length            102.319588
# Area code                 437.543814
# Number vmail messages       5.170103
# Total day minutes         205.181186
# Total day calls           101.195876
# Total day charge           34.881340
# Total eve minutes         209.385309
# Total eve calls            99.948454
# Total eve charge           17.797861
# Total night minutes       205.307216
# Total night calls         100.682990
# Total night charge          9.238892
# Total intl minutes         10.819330
# Total intl calls            4.051546
# Total intl charge           2.921727
# Customer service calls      2.206186
# Churn                       1.000000
# dtype: float64

# %%
### Retained Analysis of All the Columns
telecom_data[telecom_data['Churn']== 0].mean()
# Out:
# Account length            100.330992
# Area code                 437.420983
# Number vmail messages       8.507463
# Total day minutes         175.104346
# Total day calls           100.159350
# Total day charge           29.768266
# Total eve minutes         198.853380
# Total eve calls           100.036435
# Total eve charge           16.902809
# Total night minutes       200.464091
# Total night calls         100.007902
# Total night charge          9.020975
# Total intl minutes         10.137840
# Total intl calls            4.538191
# Total intl charge           2.737709
# Customer service calls      1.453029
# Churn                       0.000000
# dtype: float64

# %%
### How much time does a user spend on a Day Call?
telecom_data[telecom_data['Churn']== 1]['Total day minutes'].mean()
# Out:
# 205.1811855670104

# %%
telecom_data[telecom_data['Churn']== 1]['Total eve minutes'].mean()
# Out:
# 209.38530927835052

# %%
telecom_data[telecom_data['Churn']== 1]['Total night minutes'].mean()
# Out:
# 205.30721649484514

# %%
telecom_data.groupby(['State','Churn']).size()
# Out:
# State  Churn
# AK     0        40
#        1         3
# AL     0        59
#        1         7
# AR     0        36
#                 ..
# WI     1         4
# WV     0        81
#        1         7
# WY     0        58
#        1         8
# Length: 102, dtype: int64

# %%
f = {'No':False,'Yes': True}
f
# Out:
# {'No': False, 'Yes': True}

# %%
telecom_data['International plan'] = telecom_data['International plan'].map(f)

# %%
g = {'No':0,'Yes': 1}
g
# Out:
# {'No': 0, 'Yes': 1}

# %%
telecom_data['Voice mail plan'] = telecom_data['Voice mail plan'].map(g)

# %%
col = ['Total day calls','Total eve calls','Total night calls']
telecom_data.groupby(['Churn','International plan'])[col].min()
# Out:
#                           Total day calls  Total eve calls  Total night calls
# Churn International plan
# 0     False                             0                0                 33
#       True                             51               58                 48
# 1     False                             0               48                 49
#       True                             42               60                 53

# %%
import numpy as np
col = ['Total day calls','Total eve calls','Total night calls']
telecom_data.groupby('Churn')[col].agg([np.mean,np.std,np.max])
# Out:
#       Total day calls                 Total eve calls                  \
#                  mean        std amax            mean        std amax
# Churn
# 0          100.159350  19.681914  160      100.036435  20.258800  170
# 1          101.195876  21.705279  156       99.948454  19.605474  159
#
#       Total night calls
#                    mean        std amax
# Churn
# 0            100.007902  19.307282  166
# 1            100.682990  20.074667  158

# %%
pd.crosstab(telecom_data['Churn'],telecom_data['International plan'])
# Out:
# International plan  False  True
# Churn
# 0                    2126    152
# 1                     270    118

# %%
pd.crosstab(telecom_data['State'],telecom_data['Voice mail plan'])
# Out:
# Voice mail plan   0   1
# State
# AK               32  11
# AL               50  16
# AR               37  10
# AZ               32  13
# CA               15   9
# CO               42  17
# CT               47  12
# DC               32  13
# DE               38  13
# FL               36  18
# GA               30  19
# HI               31  13
# IA               28  10
# ID               34  22
# IL               34  11
# IN               41  13
# KS               39  13
# KY               31  12
# LA               26   9
# MA               35  17
# MD               46  14
# ME               36  13
# MI               44  14
# MN               49  21
# MO               37  14
# MS               32  16
# MT               33  20
# NC               39  17
# ND               26  18
# NE               31  14
# NH               33  10
# NJ               35  15
# NM               35   9
# NV               49  12
# NY               51  17
# OH               43  23
# OK               38  14
# ...

# %%
telecom_data.pivot_table(col,['State'],aggfunc= ['mean','std']).sort_index(ascending = False)
# Out:
#                  mean                                               std  \
#       Total day calls Total eve calls Total night calls Total day calls
# State
# WY         101.333333       99.166667        102.787879       22.588175
# WV         104.500000       99.363636        100.715909       21.229453
# WI          97.000000       99.081967         98.426230       20.346171
# WA         100.520833       95.750000        103.750000       17.593507
# VT         101.035088       96.982456        103.578947       24.107620
# VA         105.910448      100.462687         93.104478       19.184694
# UT          99.683333       97.866667        100.733333       20.761349
# TX         101.236364      101.254545         99.290909       12.738050
# TN          99.658537      105.853659         91.000000       21.104040
# SD          93.918367       98.367347         94.081633       22.709063
# SC         101.571429      100.714286         99.816327       21.440810
# ...

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
a = sns.barplot(x = 'day', y = 'total_bill',data = tips)
a.set(xlabel = 'Day_Name', ylabel = 'Total_bill', title = "The Day wise Analysis")
# Out:
# [Text(0, 0.5, 'Total_bill'),
#  Text(0.5, 0, 'Day_Name'),
#  Text(0.5, 1.0, 'The Day wise Analysis')]

# %%
a = sns.barplot(x = 'total_bill', y = 'day',data = tips)
a.set(xlabel = 'Total_bill', ylabel = 'Day', title = "The Day wise Analysis")
# Out:
# [Text(0, 0.5, 'Day'),
#  Text(0.5, 0, 'Total_bill'),
#  Text(0.5, 1.0, 'The Day wise Analysis')]

# %%
a = sns.barplot(x = 'day', y = 'total_bill',hue = 'smoker',data = tips,palette= 'RdBu')
a.set(xlabel = 'Day_Name', ylabel = 'Total_bill', title = "The Day wise Analysis")
# Out:
# [Text(0, 0.5, 'Total_bill'),
#  Text(0.5, 0, 'Day_Name'),
#  Text(0.5, 1.0, 'The Day wise Analysis')]

# %%
sns.pairplot(tips,hue = 'sex',vars = ['total_bill','tip','size'])

# %%
sns.boxplot(x = 'day',y = 'total_bill',hue = 'sex',data = tips,palette= 'rainbow')

# %%
sns.countplot(x = tips['smoker'])

# %%
sns.regplot(x = 'total_bill', y = 'tip',data = tips)

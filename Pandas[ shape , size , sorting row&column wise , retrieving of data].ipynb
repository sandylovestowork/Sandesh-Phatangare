# %%
import pandas as pd    ###importing pandas

# %%
### importing file named titles
data = pd.read_csv('D:\//titles.csv')

# %%
### to get shapes (rows, columns)
data.shape
# Out:
# (230621, 2)

# %%
### Creating a df in which i can use top 50 entries of row
df = data.head(50)

# %%
df
# Out:
#                                          title  year
# 0                               The Rising Son  1990
# 1                      The Thousand Plane Raid  1969
# 2                             Crucea de piatra  1993
# 3                                      Country  2000
# 4                                   Gaiking II  2011
# 5                                  Medusa (IV)  2015
# 6               The Fresh Air Will Do You Good  2008
# 7                           Alex in Wonderland  1970
# 8                                   L'outsider  2016
# 9                       Do Outro Lado do Mundo  2008
# 10                               Slave by Name  2017
# 11                              The Abductress  2014
# 12                    Poka Makorer Ghar Bosoti  1996
# 13                                   Hi, Buddy  1943
# 14                             Los siete locos  1973
# 15                                  Panic Room  2002
# 16                       Io sono un autarchico  1976
# ...

# %%
###Retrieve a single column
df.year//10*10
# Out:
# 0     1990
# 1     1960
# 2     1990
# 3     2000
# 4     2010
# 5     2010
# 6     2000
# 7     1970
# 8     2010
# 9     2000
# 10    2010
# 11    2010
# 12    1990
# 13    1940
# 14    1970
# 15    2000
# 16    1970
# 17    2010
# 18    1960
# 19    1990
# 20    1910
# 21    2000
# 22    1980
# 23    1990
# 24    2010
# 25    1910
# 26    1990
# 27    2000
# 28    2010
# 29    2010
# 30    2010
# 31    1990
# 32    2010
# 33    2000
# 34    1990
# 35    1990
# 36    2010
# 37    2000
# 38    2010
# 39    1950
# 40    1990
# 41    2000
# 42    1910
# 43    2010
# 44    1950
# 45    1940
# 46    1990
# 47    2010
# 48    2010
# 49    2000
# Name: year, dtype: int64

# %%
### sorting years greater than 2010
df[df.year>2010]
# Out:
#                                       title  year
# 4                                Gaiking II  2011
# 5                               Medusa (IV)  2015
# 8                                L'outsider  2016
# 10                            Slave by Name  2017
# 11                           The Abductress  2014
# 17                   Shobhna's Seven Nights  2012
# 24                            The Syndicate  2011
# 28  The Majestic Life of Queen Elizabeth II  2013
# 29                               Velvet Rut  2012
# 30                               Dreamscape  2011
# 32                        The Hidden Corner  2016
# 36                           Dressing Table  2016
# 38                                  Pruebas  2011
# 43                                Incognita  2012
# 47                            Schadenfreude  2016
# 48                                   Stolen  2012

# %%
### sorting in two columns with bitwise operator
df[(df.year>2010) & (df.year<2015)]
# Out:
#                                       title  year
# 4                                Gaiking II  2011
# 11                           The Abductress  2014
# 17                   Shobhna's Seven Nights  2012
# 24                            The Syndicate  2011
# 28  The Majestic Life of Queen Elizabeth II  2013
# 29                               Velvet Rut  2012
# 30                               Dreamscape  2011
# 38                                  Pruebas  2011
# 43                                Incognita  2012
# 48                                   Stolen  2012

# %%
### Retrieve and sorting of data according to name[macbeth in coloumns
data[data['title'] == "Macbeth"].sort_values('year',ascending=False)
# Out:
#           title  year
# 168225  Macbeth  2017
# 146810  Macbeth  2016
# 125469  Macbeth  2015
# 154409  Macbeth  2014
# 11539   Macbeth  2013
# 150447  Macbeth  2009
# 55416   Macbeth  2006
# 131922  Macbeth  2004
# 86470   Macbeth  2003
# 25430   Macbeth  1998
# 16930   Macbeth  1997
# 203220  Macbeth  1987
# 157917  Macbeth  1948
# 67313   Macbeth  1916
# 4162    Macbeth  1913

# %%
### sorting data of specific year with title
data[data['year'] == 2000].sort_values('title')
# Out:
#                                                     title  year
# 14798                                               $pent  2000
# 72468                             'Di ko kayang tanggapin  2000
# 33171                         (I'm Living) A Charmed Life  2000
# 217634                     ...und das ist erst der Anfang  2000
# 190937                                  01412 pasasingeum  2000
# ...                                                   ...   ...
# 175122                         Zorrita: Passion's Avenger  2000
# 27748                                      Zverinye Voiny  2000
# 223155                     Zvyozdochka moya nenaglyadnaya  2000
# 107087  Zycie jako smiertelna choroba przenoszona drog...  2000
# 117247                              Zzikhimyeon jukneunda  2000
#
# [2736 rows x 2 columns]

# %%
data[data['title'] == "Macbeth"].sort_values('year').tail()
# Out:
#           title  year
# 11539   Macbeth  2013
# 154409  Macbeth  2014
# 125469  Macbeth  2015
# 146810  Macbeth  2016
# 168225  Macbeth  2017

# %%
###length of data
len(data)
# Out:
# 230621

# %%
data.columns
# Out:
# Index(['title', 'year'], dtype='object')
